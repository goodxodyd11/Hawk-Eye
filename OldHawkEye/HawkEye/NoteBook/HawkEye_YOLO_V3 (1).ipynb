# %%
import os
from os.path import exists, join, basename, splitext

git_repo_url = 'https://github.com/eggbread/HawkEye'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # clone and install dependencies
  # !git clone -q $git_repo_url
  #!cd $project_name && pip install -q -r requirement.txt
  
import sys
sys.path.append(project_name)
import time
import matplotlib
import matplotlib.pylab as plt
plt.rcParams["axes.grid"] = False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
if not exists('yolov3.weights'):
  # !wget -q https://drive.google.com/open?id=1xO71kVA-eZloQ5NODk8S7swvHXKN17EF

# %%
IMAGE_URL = 'https://image.shutterstock.com/image-photo/spring-colored-birds-flirting-natural-260nw-1100237423.jpg'

print(IMAGE_URL)
image_file = basename(IMAGE_URL)
# image_file = 'bird.jpg'
print(image_file)
# !wget -q -O $image_file $IMAGE_URL
plt.figure(figsize=(15, 15))
plt.imshow(matplotlib.image.imread(image_file))
# Out:
# https://image.shutterstock.com/image-photo/spring-colored-birds-flirting-natural-260nw-1100237423.jpg
# spring-colored-birds-flirting-natural-260nw-1100237423.jpg

# %%
# !cd HawkEye/Code && python detect.py --weights ../../yolov3.weights --images ../../$image_file --det .. #image
url = '/content/video.mp4'
# !cd HawkEye/Code && python video_demo.py --weights ../../yolov3.weights --video $url  #video

# plt.figure(figsize=(15, 15))
# plt.imshow(matplotlib.image.imread('det_%s' % image_file))
# Out:
# Loading network.....
# Network successfully loaded
# FPS of the video is 13.49
# FPS of the video is 14.82
# FPS of the video is 15.24
# FPS of the video is 15.52
# FPS of the video is 15.88
# FPS of the video is 16.40
# FPS of the video is 16.73
# FPS of the video is 17.04
# FPS of the video is 17.37
# FPS of the video is 17.67
# FPS of the video is 17.84
# FPS of the video is 18.05
# FPS of the video is 18.27
# FPS of the video is 18.49
# FPS of the video is 18.56
# FPS of the video is 18.77
# FPS of the video is 18.96
# FPS of the video is 19.14
# FPS of the video is 19.30
# FPS of the video is 19.40
# FPS of the video is 19.52
# FPS of the video is 19.63
# FPS of the video is 19.74
# FPS of the video is 19.83
# FPS of the video is 19.89
# FPS of the video is 19.98
# FPS of the video is 19.99
# FPS of the video is 20.05
# FPS of the video is 20.07
# FPS of the video is 20.15
# FPS of the video is 20.21
# FPS of the video is 20.29
# FPS of the video is 20.33
# ...

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# !/content/drive/My%20Drive/dataset/video.avi
# Out:
# /bin/bash: /content/drive/My%20Drive/dataset/video.avi: No such file or directory
